# %%
# Question 1
#dataset link: https://www.kaggle.com/datasets/hasibalmuzdadid/asia-cup-cricket-1984-to-2022?resource=download
#importing pandas lib to support dataframes and plotting graphs
import pandas as pd
import numpy as np

# %%
#Question 2
#read data from csv
asia_cup_cricket_data = pd.read_csv("asiacup.csv")

#print top 5 rows
asia_cup_cricket_data.head()
# Out:
#         Team   Opponent Format   Ground  Year  Toss Selection  Run Scored  \
# 0   Pakistan  Sri Lanka    ODI  Sharjah  1984  Lose   Batting       187.0
# 1  Sri Lanka   Pakistan    ODI  Sharjah  1984   Win   Bowling       190.0
# 2      India  Sri Lanka    ODI  Sharjah  1984   Win   Bowling        97.0
# 3  Sri Lanka      India    ODI  Sharjah  1984  Lose   Batting        96.0
# 4      India   Pakistan    ODI  Sharjah  1984   Win   Batting       188.0
#
#    Wicket Lost  Fours  Sixes  Extras  Run Rate  Avg Bat Strike Rate  \
# 0          9.0    9.0    3.0    21.0      4.06                52.04
# 1          5.0   11.0    1.0    26.0      4.36                68.51
# 2          0.0    9.0    0.0    14.0      4.47                60.48
# 3         10.0    7.0    0.0     8.0      2.34                25.74
# 4          4.0   13.0    3.0    17.0      4.08                60.21
#
#    Highest Score  Wicket Taken  Given Extras  Highest Individual wicket  \
# ...

# %%
#Question 3
#Descriptive statistics for all Quantitative and Categorical variables
asia_cup_cricket_data.describe(include="all")
# Out:
#              Team   Opponent Format  Ground         Year  Toss Selection  \
# count         234        234    234     234   234.000000   234       234
# unique          7          7      2      18          NaN     3         2
# top     Sri Lanka  Sri Lanka    ODI  Mirpur          NaN  Lose   Batting
# freq           55         55    206      48          NaN   117       117
# mean          NaN        NaN    NaN     NaN  2007.615385   NaN       NaN
# std           NaN        NaN    NaN     NaN    10.512079   NaN       NaN
# min           NaN        NaN    NaN     NaN  1986.000000   NaN       NaN
# 25%           NaN        NaN    NaN     NaN  1999.000000   NaN       NaN
# 50%           NaN        NaN    NaN     NaN  2010.000000   NaN       NaN
# 75%           NaN        NaN    NaN     NaN  2016.000000   NaN       NaN
# max           NaN        NaN    NaN     NaN  2024.000000   NaN       NaN
#
#         Run Scored  Wicket Lost       Fours       Sixes      Extras  \
# ...

# %%
#Question 4
#transform the year column to increase the year by 1
asia_cup_cricket_data['Year'] = asia_cup_cricket_data['Year']+1
#print top 5 rows
asia_cup_cricket_data.head()
# Out:
#         Team   Opponent Format   Ground  Year  Toss Selection  Run Scored  \
# 0   Pakistan  Sri Lanka    ODI  Sharjah  1987  Lose   Batting       187.0
# 1  Sri Lanka   Pakistan    ODI  Sharjah  1987   Win   Bowling       190.0
# 2      India  Sri Lanka    ODI  Sharjah  1987   Win   Bowling        97.0
# 3  Sri Lanka      India    ODI  Sharjah  1987  Lose   Batting        96.0
# 4      India   Pakistan    ODI  Sharjah  1987   Win   Batting       188.0
#
#    Wicket Lost  Fours  Sixes  Extras  Run Rate  Avg Bat Strike Rate  \
# 0          9.0    9.0    3.0    21.0      4.06                52.04
# 1          5.0   11.0    1.0    26.0      4.36                68.51
# 2          0.0    9.0    0.0    14.0      4.47                60.48
# 3         10.0    7.0    0.0     8.0      2.34                25.74
# 4          4.0   13.0    3.0    17.0      4.08                60.21
#
#    Highest Score  Wicket Taken  Given Extras  Highest Individual wicket  \
# ...

# %%
#Question 5
#plot year and run rate
asia_cup_cricket_data.plot(x ='Year', y='Run Rate')

# %%
#Question 5
#plot year and fours in scatter plot
asia_cup_cricket_data.plot(x='Year', y='Fours', kind = 'scatter')
